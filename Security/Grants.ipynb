# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG c_a_tunes_dev TO `DEs`;
GRANT CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.bronze to `DEs`;
GRANT CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.silver to `DEs`;
GRANT CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.golden to `DEs`;
GRANT CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.chinook to `DEs`;

# %% [markdown]
# Permisos external location

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-chinok` to `DataEnginers`;
