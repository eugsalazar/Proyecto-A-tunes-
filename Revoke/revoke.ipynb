# %%
# %sql
REVOKE ALL PRIVILEGES ON CATALOG c_a_tunes_dev from `DEs`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.bronze from `DEs`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.silver from `DEs`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  c_a_tunes_dev.golden from `DEs`;

# %%
# %sql
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` from `DEs`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` from `DEs`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` from `DEs`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` from `DEs`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` from `DEs`;
